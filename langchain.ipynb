# %%
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
from langchain_openai import AzureChatOpenAI
import os

# %%
llm = AzureChatOpenAI(
    api_key = os.getenv("AZURE_OPENAI_API_KEY"),
    api_version=os.getenv("AZURE_OPENAI_API_VERSION"),
    azure_deployment = os.getenv("AZURE_OPENAI_DEPLOYMENT_NAME"),
    azure_endpoint= os.getenv("AZURE_OPENAI_ENDPOINT"),
)

# %%
#langchain tracking
os.environ["LANGSMITH_API_KEY"] = os.getenv("LANGSMITH_API_KEY")
os.environ["LANGSMITH_PROJECT"] = os.getenv("LANGSMITH_PROJECT")
os.environ["LANGSMITH_PROJECT"] = os.getenv("LANGSMITH_PROJECT")
os.environ["LANGSMITH_ENDPOINT"] = os.getenv("LANGSMITH_ENDPOINT")

# %%
llm.invoke("What is machine learning")
# Out:
# AIMessage(content='Machine learning is a branch of artificial intelligence where computers learn patterns from data and use those patterns to make predictions or decisions without being explicitly programmed for every possible situation.\n\nKey points:\n\n- Instead of writing fixed rules, you give the system:\n  - **Data** (examples, past records, images, text, etc.)\n  - **A task** (e.g., classify emails as spam/not spam, predict house prices)\n- The system trains a **model** that captures relationships in the data.\n- Once trained, the model can:\n  - Generalize to **new, unseen data**\n  - Improve over time as it sees more data (in many setups)\n\nCommon types:\n- **Supervised learning** – Learn from labeled examples (input → known output).\n- **Unsupervised learning** – Find structure in unlabeled data (e.g., clustering customers).\n- **Reinforcement learning** – Learn by trial and error with rewards (e.g., game-playing agents).\n\nIf you say what background you have (e.g., high school, some programming, etc.), I can tailor a more detailed or simpler explanation.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 237, 'prompt_tokens': 10, 'total_tokens': 247, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0}, 'latency_checkpoint': {'engine_tbt_ms': 12, 'engine_ttft_ms': 311, 'engine_ttlt_ms': 3190, 'pre_inference_ms': 155, 'service_tbt_ms': 12, 'service_ttft_ms': 941, 'service_ttlt_ms': 3816, 'total_duration_ms': 3669, 'user_visible_ttft_ms': 786}}, 'model_provider': 'openai', 'model_name': 'gpt-5.1-2025-11-13', 'system_fingerprint': None, 'id': 'chatcmpl-EEBFR0h1bc32EJLUSxonOUzsv6LoX', 'service_tier': 'default', 'prompt_filter_results': [{'prompt_index': 0, 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'jailbreak': {'detected': False, 'filtered': False}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}], 'finish_reason': 'stop', 'logprobs': None, 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'protected_material_code': {'detected': False, 'filtered': False}, 'protected_material_text': {'detected': False, 'filtered': False}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}, id='lc_run--01a01464-a0e7-7ca3-ae35-3d081025d39f-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 10, 'output_tokens': 237, 'total_tokens': 247, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
from langchain_core.prompts import ChatPromptTemplate

# %%
prompts = ChatPromptTemplate.from_messages(
    [
       ("system", "You're an ai assistant that answers questions precisely"),
       ("user", "{input}") 
    ]
)

# %%
chain = prompts | llm
results = chain.invoke({"input": "What is langchain"})

# %%
results
# Out:
# AIMessage(content='LangChain is an open‑source framework (in Python and JavaScript) for building applications that use large language models (LLMs).\n\nIt focuses on helping you:\n\n1. **Connect to LLMs and tools**\n   - Works with models like OpenAI, Anthropic, local models, etc.\n   - Lets you call external tools/APIs (search, databases, code execution).\n\n2. **Build “chains” of operations**\n   - Combine multiple steps, e.g.:\n     - Take user input → call an LLM → call a database → format an answer.\n   - Supports branching, looping, and complex workflows.\n\n3. **Use prompts and templates**\n   - Manage reusable prompt templates.\n   - Insert variables (like user input or context) into prompts reliably.\n\n4. **Handle memory / context**\n   - Add “memory” so the app can carry information across multiple turns in a conversation.\n   - Integrate with vector stores for retrieval‑augmented generation (RAG).\n\n5. **Integrate data sources**\n   - Load and split documents (PDFs, web pages, etc.).\n   - Store and search embeddings using vector databases.\n\nIn short, LangChain is a toolkit to turn raw LLMs into full applications: chatbots, RAG systems, agents, and other AI-powered workflows.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 278, 'prompt_tokens': 22, 'total_tokens': 300, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0}, 'latency_checkpoint': {'engine_tbt_ms': 14, 'engine_ttft_ms': 310, 'engine_ttlt_ms': 4100, 'pre_inference_ms': 1118, 'service_tbt_ms': 14, 'service_ttft_ms': 2047, 'service_ttlt_ms': 5820, 'total_duration_ms': 4711, 'user_visible_ttft_ms': 928}}, 'model_provider': 'openai', 'model_name': 'gpt-5.1-2025-11-13', 'system_fingerprint': None, 'id': 'chatcmpl-EEBc2XDUHzEaTvduByZaFA23DsHJG', 'service_tier': 'default', 'prompt_filter_results': [{'prompt_index': 0, 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'jailbreak': {'detected': False, 'filtered': False}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}], 'finish_reason': 'stop', 'logprobs': None, 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'protected_material_code': {'detected': False, 'filtered': False}, 'protected_material_text': {'detected': False, 'filtered': False}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}, id='lc_run--01a0147a-050c-7651-a164-8abd424e991d-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 22, 'output_tokens': 278, 'total_tokens': 300, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
#Stroutputparser
from langchain_core.output_parsers import StrOutputParser
output_parser = StrOutputParser()
chain = prompts | llm | output_parser

# %%
response = chain.invoke({"input": "What is langsmith"})

# %%
response
# Out:
# 'LangSmith is a developer platform from LangChain for building, testing, and monitoring AI applications that use LLMs.\n\nIn practical terms, it helps you:\n\n- **Trace and debug**: See detailed call graphs of your LLM chains/agents (inputs, outputs, intermediate steps, latencies).\n- **Evaluate quality**: Run evaluations (automatic or human) on prompts, chains, or full workflows to compare models, prompts, or versions.\n- **Monitor in production**: Track performance, errors, model usage, and costs over time.\n- **Manage datasets & runs**: Store example inputs/outputs, create test sets, and replay them against new versions of your app.\n\nIt integrates tightly with LangChain but can also be used with non-LangChain code via their APIs.'
